# %%
import os
import openai
import json
# export OPENAI_API_KEY="您的API密钥"
openai.api_key = os.getenv("OPENAI_API_KEY")
openai.api_key = "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"

completion = openai.ChatCompletion.create(
  model="gpt-3.5-turbo",
  messages=[
    {"role": "system", "content": "提示：您可以问我任何与音乐相关的问题。"},
    {"role": "user", "content": "什么是贝多芬的第五交响乐？"},
    {"role": "assistant", "content": "贝多芬的第五交响乐是。 （详细描述)"}
  ]
)

resp = completion.choices[0].message

print(resp["content"])
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[11], line 8
#       5 openai.api_key = os.getenv("OPENAI_API_KEY")
#       6 openai.api_key = "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"
# ----> 8 completion = openai.ChatCompletion.create(
#       9   model="gpt-3.5-turbo",
#      10   messages=[
#      11     {"role": "system", "content": "提示：您可以问我任何与音乐相关的问题。"},
#      12     {"role": "user", "content": "什么是贝多芬的第五交响乐？"},
#      13     {"role": "assistant", "content": "贝多芬的第五交响乐是。 （详细描述)"}
#      14   ]
#      15 )
#      17 resp = completion.choices[0].message
#      19 print(resp["content"])
#
# File /opt/homebrew/lib/python3.11/site-packages/openai/api_resources/chat_completion.py:25, in ChatCompletion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
# ...
